# %% [markdown]
# <a href="https://colab.research.google.com/github/Araihan413/IlmuData-Semester6/blob/main/tugas_Modul_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## latihan menggunakan github di google colab

# %%
# Out:
# fatal: not a git repository (or any of the parent directories): .git
